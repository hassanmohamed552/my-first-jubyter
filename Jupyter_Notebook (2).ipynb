# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **name:Hassan Mohamed** <br>
#  electrical engineer

# %% [markdown]
# *using data science can help me to enhance my skill set to increase my chances to find better job*

# %% [markdown]
# ### Multiplication code

# %%
a=1
b=2
print(a*b)
# Out:
# 2

# %% [markdown]
# [Link to Google](href="https://www.google.com") <br>
# ![image.png](attachment:5918687f-02fb-4a9f-b02c-6c1435737287.png)
# 1. google
# 2. bing
# 3. duckduckgo
